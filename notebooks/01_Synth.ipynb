# %%
import sys, os

# adjust this if your notebook isn't one level below the project root
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

from synth_city.scm.graph import SynthCity

# %%
city = SynthCity(n_people=5000, seed=0)
observational_df = city.sample()
observational_df.head()
# Out:
#    min_wage  tax_rate  transit_subsidy   ability  risk_tolerance  \
# 0      7.25       0.2              0.0  0.125730       -0.179974
# 1      7.25       0.2              0.0 -0.132105        1.808723
# 2      7.25       0.2              0.0  0.640423        0.344974
# 3      7.25       0.2              0.0  0.104900       -0.696425
# 4      7.25       0.2              0.0 -0.535669        0.476839
#
#    health_endowment  parental_ses        age  education  \
# 0          0.489408      0.169740  41.837132   9.917437
# 1         -1.336546     -1.065018  31.639714   6.988339
# 2         -1.113831     -0.001891  40.016486  10.189397
# 3         -0.452952      0.048420  48.546242  11.624545
# 4          1.679824      0.419377  54.829763   8.877026
#
#    social_network_position        income  mobility_access  preferences  \
# 0                 0.254880  43115.239757         0.914102     1.078761
# 1                -2.198727  27711.559480         0.015412    -0.971366
# 2                -1.036224  48257.437153         0.650680     0.391620
# 3                 1.088651  55928.792419         0.893252     3.049165
# 4                 0.550359  40367.940167         0.555859     0.920784
#
#      health
# 0  5.204702
# 1 -7.377963
# 2 -3.401109
# 3 -1.321107
# 4  9.819207

# %%
# Ground-truth intervention: what happens if min wage goes to $15?
treated_city = city.do(min_wage=15.0)
interventional_df = treated_city.sample()

# %%
true_ate = interventional_df["income"].mean() - observational_df["income"].mean()
